# %%
# %matplotlib inline

# %% [markdown]
# http://louistiao.me/posts/notebooks/save-matplotlib-animations-as-gifs/
#
# https://www.youtube.com/watch?v=LZrgpPflEzM
#
# interactive: http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-as-interactive-javascript-widgets/

# %%
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
import cartopy.crs as ccrs

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(1,1,1, projection=ccrs.PlateCarree())

ax.coastlines()
ax.set_global()

x = [0, 50, 100]
y = [0, 0, 0]

scat = ax.scatter(x=x, y=y, transform=ccrs.PlateCarree())

# %%
# animation function. This is called sequentially
def animate(i, fig, scat):
    scat.set_offsets(([0, i], [50, i], [100, i]))
    return scat,

# %%
# call the animator. blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, fargs=(fig, scat),
                               frames=100, interval=20, blit=True)

# %%
HTML(anim.to_html5_video())
# Out:
# <video width="864" height="720" controls autoplay loop>
#   <source type="video/mp4" src="...
